# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('Algerian_forest_fires_dataset.csv')

# %%
data.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
data.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
data.loc[:122,'region']=0
data.loc[122:,'region']=1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
data[['region']]=data[['region']].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  region       247 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 28.1+ KB

# %%
data=data.dropna().reset_index(drop=True)

# %%
data.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# region         0
# dtype: int64

# %%
data.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    region
# 122  FWI  Classes         1

# %%
data=data.drop(122).reset_index(drop=True)

# %%
data
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    region
# 0    0.5   not fire          0
# 1    0.4   not fire          0
# 2    0.1   not fire          0
# 3      0   not fire          0
# 4    0.5   not fire          0
# ..   ...           ...     ...
# 238  6.5       fire          1
# 239    0   not fire          1
# 240  0.2   not fire          1
# 241  0.7   not fire          1
# 242  0.5  not fire           1
#
# [243 rows x 15 columns]

# %%
data.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    region
# 122  not fire          1

# %%
data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'region'],
#       dtype='object')

# %%
#fix spaces in columan name
data.columns=data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df=data

# %%
#let save clean dataset
df.to_csv('Algerian_forest_fires_clean_dataset.csv',index=False)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes  region
# 0    0.5   not fire          0
# 1    0.4   not fire          0
# 2    0.1   not fire          0
# 3      0   not fire          0
# 4    0.5   not fire          0
# ..   ...           ...     ...
# 238  6.5       fire          1
# 239    0   not fire          1
# 240  0.2   not fire          1
# 241  0.7   not fire          1
# 242  0.5  not fire           1
#
# [243 rows x 15 columns]

# %%
##Explority data analysis
df_copy=df.drop(['day','month','year'],axis=1)
df_copy
# Out:
#     Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  FWI       Classes  \
# 0            29  57  18     0  65.7  3.4   7.6  1.3   3.4  0.5   not fire
# 1            29  61  13   1.3  64.4  4.1   7.6    1   3.9  0.4   not fire
# 2            26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1   not fire
# 3            25  89  13   2.5  28.6  1.3   6.9    0   1.7    0   not fire
# 4            27  77  16     0  64.8    3  14.2  1.2   3.9  0.5   not fire
# ..          ...  ..  ..   ...   ...  ...   ...  ...   ...  ...           ...
# 238          30  65  14     0  85.4   16  44.5  4.5  16.9  6.5       fire
# 239          28  87  15   4.4  41.1  6.5     8  0.1   6.2    0   not fire
# 240          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4  0.2   not fire
# 241          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1  0.7   not fire
# 242          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8  0.5  not fire
#
#      region
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1
#
# [243 rows x 12 columns]

# %%
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy['Classes'].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %%
df_copy
# Out:
#     Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  FWI  Classes  \
# 0            29  57  18     0  65.7  3.4   7.6  1.3   3.4  0.5        0
# 1            29  61  13   1.3  64.4  4.1   7.6    1   3.9  0.4        0
# 2            26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1        0
# 3            25  89  13   2.5  28.6  1.3   6.9    0   1.7    0        0
# 4            27  77  16     0  64.8    3  14.2  1.2   3.9  0.5        0
# ..          ...  ..  ..   ...   ...  ...   ...  ...   ...  ...      ...
# 238          30  65  14     0  85.4   16  44.5  4.5  16.9  6.5        1
# 239          28  87  15   4.4  41.1  6.5     8  0.1   6.2    0        0
# 240          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4  0.2        0
# 241          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1  0.7        0
# 242          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8  0.5        0
#
#      region
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1
#
# [243 rows x 12 columns]

# %%
#density plot
plt.style.use('seaborn')
df_copy.hist(bins=30,figsize=(20,15))
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15584\2725857933.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
#percentage of pie chat
percentage=df_copy['Classes'].value_counts(normalize=True)*100

# %%
classlabels=['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("pie chart")
# Out:
# Text(0.5, 1.0, 'pie chart')

# %%
#correlation
df_copy.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15584\3687227434.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_copy.corr()
#           Classes    region
# Classes  1.000000  0.162347
# region   0.162347  1.000000

# %%
df.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15584\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#         region
# region     1.0

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15584\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
#boxsplot
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
#monthly fire analysis
dftemp=df.loc[df['region']==1]
plt.subplots(figsize=(13,9))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
#train the mode

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
X=df.drop('FWI',axis=1)
y=df['FWI']

# %%
X
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#       Classes  region
# 0    not fire       0
# 1    not fire       0
# 2    not fire       0
# 3    not fire       0
# 4    not fire       0
# ..        ...     ...
# 238      fire       1
# 239  not fire       1
# 240  not fire       1
# 241  not fire       1
# 242  not fire       1
#
# [243 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 14), (61, 14))
